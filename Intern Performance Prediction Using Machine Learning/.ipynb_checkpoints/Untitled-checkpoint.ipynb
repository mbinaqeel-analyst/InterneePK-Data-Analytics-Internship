# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("intern_performance_dataset.csv")

df.head()
# Out:
#    Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# 0        362              83.810694            15.0        7.014365
# 1         74              97.231921            25.0        8.236330
# 2        375              72.421732            16.0        7.259562
# 3        156              88.630829            23.0        9.492090
# 4        105              98.613497            21.0        9.900124
#
#    Participation_Score  Learning_Assessment_Score  Avg_Submission_Delay_Days  \
# 0             5.021973                  63.156155                   3.932205
# 1             8.210449                  79.106645                   1.785343
# 2             5.589526                  51.345607                   4.748364
# 3             7.727412                        NaN                   0.869655
# 4             7.227590                  82.793052                   0.036781
#
#    Weekly_Activity_Hours  Meetings_Attended  Tasks_Completed  \
# 0                    NaN               13.0             11.0
# 1              37.436140               17.0             22.0
# 2              18.757585               15.0             11.0
# 3              32.021426               14.0             19.0
# 4              30.693287               14.0             20.0
#
#    Task_Completion_Rate Performance_Status
# 0                  0.73         Successful
# 1                  0.88         Successful
# 2                  0.69         Successful
# 3                  0.83         Successful
# 4                  0.95         Successful

# %%
df.head(10)
# Out:
#    Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# 0        362              83.810694            15.0        7.014365
# 1         74              97.231921            25.0        8.236330
# 2        375              72.421732            16.0        7.259562
# 3        156              88.630829            23.0        9.492090
# 4        105              98.613497            21.0        9.900124
# 5        395              87.855913            21.0        6.301402
# 6        378              80.755219            21.0        7.183842
# 7        125              88.419027            30.0        9.523021
# 8         69              86.118260            22.0        8.637951
# 9        451              61.429799            18.0        2.993505
#
#    Participation_Score  Learning_Assessment_Score  Avg_Submission_Delay_Days  \
# 0             5.021973                  63.156155                   3.932205
# 1             8.210449                  79.106645                   1.785343
# 2             5.589526                  51.345607                   4.748364
# 3             7.727412                        NaN                   0.869655
# 4             7.227590                  82.793052                   0.036781
# 5             4.675417                  57.700827                   1.451727
# 6             4.782437                  54.956118                        NaN
# 7             7.619001                  88.568111                   1.037835
# 8             8.560491                  96.045719                   0.415773
# 9             4.593698                  54.134839                   5.088164
#
#    Weekly_Activity_Hours  Meetings_Attended  Tasks_Completed  \
# 0                    NaN               13.0             11.0
# 1              37.436140               17.0             22.0
# 2              18.757585               15.0             11.0
# 3              32.021426               14.0             19.0
# 4              30.693287               14.0             20.0
# 5              26.962955               12.0             16.0
# 6              30.938501               11.0             14.0
# 7              33.950509               19.0             26.0
# 8                    NaN               16.0             21.0
# 9               9.207593                5.0              9.0
#
#    Task_Completion_Rate Performance_Status
# 0                  0.73         Successful
# 1                  0.88         Successful
# 2                  0.69         Successful
# 3                  0.83         Successful
# 4                  0.95         Successful
# 5                  0.76         Successful
# 6                  0.67         Successful
# 7                  0.87         Successful
# 8                  0.95         Successful
# 9                  0.50  Needs Improvement

# %%
df.tail()
# Out:
#      Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# 495        107              91.155744            29.0        9.146876
# 496        271              79.485372            19.0        6.938270
# 497        349              84.887759            21.0        5.332424
# 498        436              57.513183            13.0        3.736084
# 499        103              89.715340            20.0        8.182573
#
#      Participation_Score  Learning_Assessment_Score  \
# 495             7.384138                  93.598657
# 496             6.524683                  74.781172
# 497             5.423893                        NaN
# 498             5.294084                  39.634865
# 499             8.900203                  94.714930
#
#      Avg_Submission_Delay_Days  Weekly_Activity_Hours  Meetings_Attended  \
# 495                   0.235502              34.443693               18.0
# 496                   1.606337              32.785974               15.0
# 497                        NaN              28.958050               14.0
# 498                   5.939753               8.510442                8.0
# 499                   0.343359              29.846751                NaN
#
#      Tasks_Completed  Task_Completion_Rate Performance_Status
# 495             25.0                  0.86         Successful
# 496             15.0                  0.79         Successful
# 497             15.0                  0.71         Successful
# 498              7.0                  0.54  Needs Improvement
# 499             19.0                  0.95         Successful

# %%
df.shape
# Out:
# (500, 12)

# %%
len(df)
# Out:
# 500

# %%
df.columns
# Out:
# Index(['Intern_ID', 'Attendance_Percentage', 'Tasks_Assigned',
#        'Feedback_Score', 'Participation_Score', 'Learning_Assessment_Score',
#        'Avg_Submission_Delay_Days', 'Weekly_Activity_Hours',
#        'Meetings_Attended', 'Tasks_Completed', 'Task_Completion_Rate',
#        'Performance_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Intern_ID                  500 non-null    int64
#  1   Attendance_Percentage      484 non-null    float64
#  2   Tasks_Assigned             491 non-null    float64
#  3   Feedback_Score             485 non-null    float64
#  4   Participation_Score        492 non-null    float64
#  5   Learning_Assessment_Score  487 non-null    float64
#  6   Avg_Submission_Delay_Days  487 non-null    float64
#  7   Weekly_Activity_Hours      491 non-null    float64
#  8   Meetings_Attended          487 non-null    float64
#  9   Tasks_Completed            486 non-null    float64
#  10  Task_Completion_Rate       487 non-null    float64
#  11  Performance_Status         500 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 47.0+ KB

# %%
df.describe()
# Out:
#         Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# count  500.000000             484.000000      491.000000      485.000000
# mean   250.500000              78.527892       20.535642        6.854272
# std    144.481833              14.528546        4.683041        2.019204
# min      1.000000              35.188946       10.000000        2.033280
# 25%    125.750000              68.999570       17.000000        5.454708
# 50%    250.500000              81.145633       21.000000        6.887896
# 75%    375.250000              89.395792       24.000000        8.586422
# max    500.000000              99.803304       30.000000        9.985930
#
#        Participation_Score  Learning_Assessment_Score  \
# count           492.000000                 487.000000
# mean              6.305210                  69.245297
# std               2.178449                  17.725703
# min               1.009961                  30.159404
# 25%               4.722330                  54.648290
# 50%               6.654460                  71.527164
# 75%               7.913736                  83.355060
# max               9.999153                  99.749006
#
#        Avg_Submission_Delay_Days  Weekly_Activity_Hours  Meetings_Attended  \
# count                 487.000000             491.000000         487.000000
# mean                    3.244127              27.454955          11.944559
# std                     2.878466               7.944160           5.036799
# min                     0.021992               8.325463           0.000000
# 25%                     1.177881              21.901411           9.000000
# 50%                     2.481588              29.011124          12.000000
# 75%                     4.311665              33.455282          16.000000
# max                    11.990034              39.975209          20.000000
#
#        Tasks_Completed  Task_Completion_Rate
# count       486.000000            487.000000
# mean         15.969136              0.751191
# std           6.062652              0.155931
# min           4.000000              0.360000
# 25%          12.000000              0.650000
# 50%          16.000000              0.760000
# 75%          20.000000              0.880000
# max          29.000000              1.000000

# %%
df.sample(5, random_state=42)
# Out:
#      Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# 361        293              71.313195            25.0        7.343511
# 73         291              79.697109            23.0        7.790957
# 374        289              68.643914            20.0        5.229251
# 155        358              80.123848            19.0        7.027947
# 104        333              69.059547            16.0        5.766240
#
#      Participation_Score  Learning_Assessment_Score  \
# 361             7.379158                  51.934738
# 73              5.484828                  71.907384
# 374             7.148506                  52.227226
# 155             4.071783                  74.999512
# 104             7.166800                  73.602510
#
#      Avg_Submission_Delay_Days  Weekly_Activity_Hours  Meetings_Attended  \
# 361                   1.602086              29.696756               11.0
# 73                    3.331938              27.244697               11.0
# 374                   3.179311              31.996260                9.0
# 155                   3.530176              22.696035               15.0
# 104                   3.902866              28.304492               10.0
#
#      Tasks_Completed  Task_Completion_Rate Performance_Status
# 361             18.0                  0.72         Successful
# 73              18.0                  0.78         Successful
# 374             13.0                  0.65         Successful
# 155             14.0                  0.74         Successful
# 104             12.0                  0.75         Successful

# %%
df.isnull().sum()
# Out:
# Intern_ID                     0
# Attendance_Percentage        16
# Tasks_Assigned                9
# Feedback_Score               15
# Participation_Score           8
# Learning_Assessment_Score    13
# Avg_Submission_Delay_Days    13
# Weekly_Activity_Hours         9
# Meetings_Attended            13
# Tasks_Completed              14
# Task_Completion_Rate         13
# Performance_Status            0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.isnull().sum()
# Out:
# Intern_ID                    0
# Attendance_Percentage        0
# Tasks_Assigned               0
# Feedback_Score               0
# Participation_Score          0
# Learning_Assessment_Score    0
# Avg_Submission_Delay_Days    0
# Weekly_Activity_Hours        0
# Meetings_Attended            0
# Tasks_Completed              0
# Task_Completion_Rate         0
# Performance_Status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
float_columns = df.select_dtypes(include=['float64']).columns
df[float_columns] = df[float_columns].round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Intern_ID                  500 non-null    int64
#  1   Attendance_Percentage      500 non-null    float64
#  2   Tasks_Assigned             500 non-null    float64
#  3   Feedback_Score             500 non-null    float64
#  4   Participation_Score        500 non-null    float64
#  5   Learning_Assessment_Score  500 non-null    float64
#  6   Avg_Submission_Delay_Days  500 non-null    float64
#  7   Weekly_Activity_Hours      500 non-null    float64
#  8   Meetings_Attended          500 non-null    float64
#  9   Tasks_Completed            500 non-null    float64
#  10  Task_Completion_Rate       500 non-null    float64
#  11  Performance_Status         500 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 47.0+ KB

# %%
df.head()
# Out:
#    Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# 0        362                  83.81            15.0            7.01
# 1         74                  97.23            25.0            8.24
# 2        375                  72.42            16.0            7.26
# 3        156                  88.63            23.0            9.49
# 4        105                  98.61            21.0            9.90
#
#    Participation_Score  Learning_Assessment_Score  Avg_Submission_Delay_Days  \
# 0                 5.02                      63.16                       3.93
# 1                 8.21                      79.11                       1.79
# 2                 5.59                      51.35                       4.75
# 3                 7.73                      69.25                       0.87
# 4                 7.23                      82.79                       0.04
#
#    Weekly_Activity_Hours  Meetings_Attended  Tasks_Completed  \
# 0                  27.45               13.0             11.0
# 1                  37.44               17.0             22.0
# 2                  18.76               15.0             11.0
# 3                  32.02               14.0             19.0
# 4                  30.69               14.0             20.0
#
#    Task_Completion_Rate Performance_Status
# 0                  0.73         Successful
# 1                  0.88         Successful
# 2                  0.69         Successful
# 3                  0.83         Successful
# 4                  0.95         Successful

# %%
df.to_csv("intern_performance_dataset_cleaned.csv", index=False)

# %%
df['Performance_Status'].value_counts()
# Out:
# Performance_Status
# Successful           347
# Needs Improvement    153
# Name: count, dtype: int64

# %%
sns.countplot(x='Performance_Status', data=df)
plt.title('Intern Performance Distribution')
plt.show()

# %%
sns.boxplot(x='Performance_Status', y='Attendance_Percentage', data=df)
plt.title('Attendance vs Performance')
plt.show()

# %%
corr = df.select_dtypes(include=['int64', 'float64']).corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.histplot(df['Attendance_Percentage'], bins=20, kde=True)
plt.title('Attendance Distribution')
plt.show()

# %%
features = ['Attendance_Percentage', 'Task_Completion_Rate', 'Feedback_Score', 'Participation_Score', 'Learning_Assessment_Score']
for feature in features:    
    plt.figure(figsize=(6,4))    
    sns.boxplot(x='Performance_Status', y=feature, data=df)    
    plt.title(f'{feature} vs Performance')    
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df["Performance_Status"] = le.fit_transform(df["Performance_Status"])

# %%
df.head()
# Out:
#    Intern_ID  Attendance_Percentage  Tasks_Assigned  Feedback_Score  \
# 0        362                  83.81            15.0            7.01
# 1         74                  97.23            25.0            8.24
# 2        375                  72.42            16.0            7.26
# 3        156                  88.63            23.0            9.49
# 4        105                  98.61            21.0            9.90
#
#    Participation_Score  Learning_Assessment_Score  Avg_Submission_Delay_Days  \
# 0                 5.02                      63.16                       3.93
# 1                 8.21                      79.11                       1.79
# 2                 5.59                      51.35                       4.75
# 3                 7.73                      69.25                       0.87
# 4                 7.23                      82.79                       0.04
#
#    Weekly_Activity_Hours  Meetings_Attended  Tasks_Completed  \
# 0                  27.45               13.0             11.0
# 1                  37.44               17.0             22.0
# 2                  18.76               15.0             11.0
# 3                  32.02               14.0             19.0
# 4                  30.69               14.0             20.0
#
#    Task_Completion_Rate  Performance_Status
# 0                  0.73                   1
# 1                  0.88                   1
# 2                  0.69                   1
# 3                  0.83                   1
# 4                  0.95                   1

# %%
print("Label Mapping:")
for index, label in enumerate(le.classes_):
    print(f"{label} → {index}")
# Out:
# Label Mapping:
# Needs Improvement → 0
# Successful → 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Intern_ID                  500 non-null    int64
#  1   Attendance_Percentage      500 non-null    float64
#  2   Tasks_Assigned             500 non-null    float64
#  3   Feedback_Score             500 non-null    float64
#  4   Participation_Score        500 non-null    float64
#  5   Learning_Assessment_Score  500 non-null    float64
#  6   Avg_Submission_Delay_Days  500 non-null    float64
#  7   Weekly_Activity_Hours      500 non-null    float64
#  8   Meetings_Attended          500 non-null    float64
#  9   Tasks_Completed            500 non-null    float64
#  10  Task_Completion_Rate       500 non-null    float64
#  11  Performance_Status         500 non-null    int64
# dtypes: float64(10), int64(2)
# memory usage: 47.0 KB

# %%
X = df.drop(
    columns=[
        "Intern_ID",
        "Performance_Status"
    ]
)

# %%
y = df["Performance_Status"]

# %%
X.head()
# Out:
#    Attendance_Percentage  Tasks_Assigned  Feedback_Score  Participation_Score  \
# 0                  83.81            15.0            7.01                 5.02
# 1                  97.23            25.0            8.24                 8.21
# 2                  72.42            16.0            7.26                 5.59
# 3                  88.63            23.0            9.49                 7.73
# 4                  98.61            21.0            9.90                 7.23
#
#    Learning_Assessment_Score  Avg_Submission_Delay_Days  \
# 0                      63.16                       3.93
# 1                      79.11                       1.79
# 2                      51.35                       4.75
# 3                      69.25                       0.87
# 4                      82.79                       0.04
#
#    Weekly_Activity_Hours  Meetings_Attended  Tasks_Completed  \
# 0                  27.45               13.0             11.0
# 1                  37.44               17.0             22.0
# 2                  18.76               15.0             11.0
# 3                  32.02               14.0             19.0
# 4                  30.69               14.0             20.0
#
#    Task_Completion_Rate
# 0                  0.73
# 1                  0.88
# 2                  0.69
# 3                  0.83
# 4                  0.95

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Performance_Status, dtype: int64

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (500, 10)
# Shape of y: (500,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train Shape:", X_train.shape)
print("X_test Shape :", X_test.shape)
print("y_train Shape:", y_train.shape)
print("y_test Shape :", y_test.shape)
# Out:
# X_train Shape: (400, 10)
# X_test Shape : (100, 10)
# y_train Shape: (400,)
# y_test Shape : (100,)

# %%
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print(model)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print("First 10 Predictions:")
print(y_pred[:10])
# Out:
# First 10 Predictions:
# [1 0 1 0 0 1 1 0 1 1]

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

comparison.head(10)
# Out:
#    Actual  Predicted
# 0       1          1
# 1       1          0
# 2       1          1
# 3       0          0
# 4       0          0
# 5       1          1
# 6       1          1
# 7       0          0
# 8       1          1
# 9       1          1

# %%
correct = (comparison["Actual"] == comparison["Predicted"]).sum()
print("Correct Predictions:", correct," Out of 100")
# Out:
# Correct Predictions: 84  Out of 100

# %%
comparison[comparison["Actual"] != comparison["Predicted"]]
# Out:
#     Actual  Predicted
# 1        1          0
# 12       0          1
# 13       1          0
# 26       0          1
# 36       0          1
# 42       0          1
# 46       1          0
# 51       0          1
# 55       0          1
# 56       0          1
# 78       0          1
# 80       0          1
# 81       1          0
# 83       1          0
# 86       0          1
# 99       0          1

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy:.2%}")
# Out:
# Model Accuracy: 84.00%

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[20 11]
#  [ 5 64]]

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Needs Improvement", "Successful"],
    yticklabels=["Needs Improvement", "Successful"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.65      0.71        31
#            1       0.85      0.93      0.89        69
#
#     accuracy                           0.84       100
#    macro avg       0.83      0.79      0.80       100
# weighted avg       0.84      0.84      0.83       100

# %%
feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance
# Out:
#                      Feature  Importance
# 9       Task_Completion_Rate    0.223835
# 8            Tasks_Completed    0.153653
# 2             Feedback_Score    0.109597
# 3        Participation_Score    0.099766
# 0      Attendance_Percentage    0.095213
# 5  Avg_Submission_Delay_Days    0.082156
# 6      Weekly_Activity_Hours    0.079460
# 7          Meetings_Attended    0.070037
# 4  Learning_Assessment_Score    0.058696
# 1             Tasks_Assigned    0.027587

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=feature_importance,
    x="Importance",
    y="Feature"
)

plt.title("Feature Importance")
plt.show()

# %%
# %pip install joblib
import joblib

joblib.dump(model, "intern_performance_model.pkl")

print("Model saved successfully!")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in C:\Users\shiek\AppData\Roaming\Python\Python313\site-packages (1.5.3)
# Note: you may need to restart the kernel to use updated packages.
# Model saved successfully!

# %%
new_intern = pd.DataFrame({
    "Attendance_Percentage": [92],
    "Tasks_Assigned": [25],
    "Feedback_Score": [9],
    "Participation_Score": [8.5],
    "Learning_Assessment_Score": [88],
    "Avg_Submission_Delay_Days": [1],
    "Weekly_Activity_Hours": [34],
    "Meetings_Attended": [17],
    "Tasks_Completed": [24],
    "Task_Completion_Rate": [0.96]
})

prediction = model.predict(new_intern)
probability = model.predict_proba(new_intern)

print("Prediction:", prediction)
print("Probability:", probability)
# Out:
# Prediction: [1]
# Probability: [[0. 1.]]
